# %%
import tensorflow as tf
from models.pix2pix import pix2pix
from models.pix2pix import pix2pix_preprocessing

# %%
pix2pix = tf.keras.models.load_model('models/pix2pix/pix2pix.h5')
# Out:
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %%
path = 'ruins_00/1_Partenón.effectsResult.0280.png'

# %%
image = pix2pix_preprocessing.load_single_image(path)
pix2pix_preprocessing.show_image(image, (10, 10))

# %%
pix2pix_preprocessing.predict_single_image(pix2pix, path, (10, 10))

# %%
prediction = pix2pix(image, training = False)
prediction_2 = pix2pix(prediction, training = False)
pix2pix_preprocessing.show_image(prediction_2, (10, 10))

# %%
path = 'ruins_00/1_Partenón.effectsResult.0003.png'

# %%
image = pix2pix_preprocessing.load_single_image(path)
pix2pix_preprocessing.show_image(image, (10, 10))

# %%
pix2pix_preprocessing.predict_single_image(pix2pix, path, (10, 10))

# %%
prediction = pix2pix(image, training = False)
prediction_2 = pix2pix(prediction, training = False)
pix2pix_preprocessing.show_image(prediction_2, (10, 10))
